# %% [markdown]
# # GENERADOR DE NUMEROS ALEATORIOS

# %%
# Para importar la libreria random
import random

# %% [markdown]
# **Función randint()**

# %%
# Generar un número entero aleatorio entre 10 y 20 (incluidos)
print(random.randint(1, 10))
# Out:
# 8

# %% [markdown]
# **Función randrange()**

# %%
# Generar un número entero aleatorio entre 10 y 110 con paso 2
print(random.randrange(10, 110, 2))
# Out:
# 94

# %% [markdown]
# **Funciones choice(), choices()**

# %%
# Elegir aleatoriamente uno (o varios, en este caso 2) colores de la lista
color=( ['rojo', 'amarillo', 'verde', 'azul', 'marrón', 'negro'])

# Un color
print (random.choice(color))

# Una pareja de colores
print (random.choices(color,k=2))

for _ in range(10):
   print('Combinación de 3 colores al azar=>',random.choices(color,weights=[1,1,1,5,1,1],k=3))
# Out:
# negro
# ['azul', 'rojo']
# Combinación de 3 colores al azar=> ['azul', 'negro', 'amarillo']
# Combinación de 3 colores al azar=> ['rojo', 'rojo', 'azul']
# Combinación de 3 colores al azar=> ['negro', 'negro', 'marrón']
# Combinación de 3 colores al azar=> ['rojo', 'azul', 'verde']
# Combinación de 3 colores al azar=> ['azul', 'rojo', 'amarillo']
# Combinación de 3 colores al azar=> ['azul', 'negro', 'negro']
# Combinación de 3 colores al azar=> ['azul', 'rojo', 'rojo']
# Combinación de 3 colores al azar=> ['azul', 'negro', 'amarillo']
# Combinación de 3 colores al azar=> ['azul', 'verde', 'amarillo']
# Combinación de 3 colores al azar=> ['azul', 'amarillo', 'azul']

# %% [markdown]
# **Función shuffle()**

# %%
# "Barajamos" con shuffle una lista de números
lista = [5, 3, 45, 27, 2, 10, 82]

# La lista tal cual
print('Lista original=>',lista)
random.shuffle(lista)

# La lista mezclada
print('Lista mezclada=>',lista)
# Out:
# Lista original=> [5, 3, 45, 27, 2, 10, 82]
# Lista mezclada=> [3, 45, 10, 82, 27, 5, 2]

# %% [markdown]
# **Función gauss()**

# %%
for _ in range(10):
   print((random.gauss(0,1.5)))
# Out:
# -0.3341779363231985
# -0.412073577637602
# -1.2953459263847473
# 0.3848825294108782
# 0.5765872553999474
# 0.26154633914131775
# 0.5516558259679858
# 0.028262554640601747
# 0.15328805859339945
# 1.199522925939246

# %% [markdown]
# **Grafica:**

# %%
import random
import matplotlib.pyplot as plt
# %matplotlib inline

campana=[random.gauss(0,1.5) for i in range(1000)]
plt.hist(campana, bins=15)
plt.show()
